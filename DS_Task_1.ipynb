# %% [markdown]
# Task 1: Exploring and Visualizing a Simple Dataset
#
# Objective:
#
#  Understand how to read, summarize, and visualize a dataset.
#
# Dataset:
#
#  Iris Dataset (CSV format, available through seaborn or other open sources)
#
#  Instructions:
#
# ●	Load the dataset using the pandas library.
#
# ●	Display dataset structure using .shape, .columns, and .head().
#
# ●	Create basic visualizations:
#
# ○ Scatter plot to analyze relationships between variables.
#
# ○ Histogram to examine data distribution.
#
# ○ Box plot to detect outliers and spread of values.
#
# ●	Use matplotlib and seaborn for visualizations.
#
# Skills:
#
# ●	Data loading and inspection using pandas
#
# ●	Basic data summarization
#
# ●	Visualization using matplotlib and seaborn

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Iris Dataset using Pandas

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display dataset structure using .shape, .columns, and .head()

# %%
print(f'Displaying shape of datasets : {df.shape}')
print(f'Displaying column of datasets : {df.columns}')
print(f'Displaying head of datasets : {df.head()}')
# Out:
# Displaying shape of datasets : (150, 5)
# Displaying column of datasets : Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# Displaying head of datasets :    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Create basic visualizations

# %%
# Scatter plot to analyze relationships between variables.
sns.scatterplot(data=df,x="sepal_length",y="sepal_width",hue="species")
plt.title("Showing Relationships between variables")
plt.show()

# Histogram to examine data distribution.
sns.histplot(data=df['sepal_length'],bins=20,kde=True)
plt.title("Showing Histogram to examine data distribution")
plt.show()

# Box plot to detect outliers and spread of values.
sns.boxplot(data=df,x="species",y="petal_length")
plt.title("Showing Box plot to detect outliers and spread of values")
plt.show()

# %% [markdown]
# # Push to Github

# %%
from google.colab import drive
drive.mount('/content/drive')

# Git setup
# !git config --global user.name "immad01dev"
# !git config --global user.email "vilen89762@gmail.com"

# Go to workspace
# %cd /content

# Remove old repo (safe reset)
# !rm -rf developershub-datascience-internship-tasks

# Clone repo
# !git clone https://github.com/immad01dev/developershub-datascience-internship-tasks.git
# %cd developershub-datascience-internship-tasks

# Copy notebook from Drive
# !cp "/content/drive/MyDrive/Colab Notebooks/DS_Task_1.ipynb" .

# Check file
# !ls

# Git add + commit
# !git add .
# !git commit -m "Added Task 1: Iris Dataset EDA"

# 🔥 IMPORTANT: set token auth
# !git remote set-url origin https://immad01dev:YOUR_TOKEN_HERE@github.com/immad01dev/developershub-datascience-internship-tasks.git

# 🚀 Push to GitHub
# !git push origin main
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# Cloning into 'developershub-datascience-internship-tasks'...
# ...
# /content/developershub-datascience-internship-tasks
# ^C
# DS_Task_1.ipynb
# [main (root-commit) 7e4d43d] Added Task 1: Iris Dataset EDA
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 DS_Task_1.ipynb
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/immad01dev/developershub-datascience-internship-tasks.git/'

# %%
# %cd /content
# !rm -rf developershub-datascience-internship-tasks

# %cd /content/developershub-datascience-internship-tasks

# !rm -rf .git
# Out:
# /content
# [Errno 2] No such file or directory: '/content/developershub-datascience-internship-tasks'
# /content
